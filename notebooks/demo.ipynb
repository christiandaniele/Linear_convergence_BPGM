# %% [markdown]
# # BPGM for Kullback--Leibler regression
#
# This notebook provides a short interactive example of the code used for the numerical experiments. The full paper runs are launched from `scripts/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.experiments import ExperimentConfig, run_experiment
from src.plotting import plot_objective_gaps

# %% [markdown]
# ## Select the experimental regime
#
# With $N=500$, the pair $(M,\lambda)$ determines the regime: $M<N$ is rank deficient, while $\lambda>0$ is regularized. Small dimensions and iteration counts are used below only for a quick demonstration.

# %%
config = ExperimentConfig(
    N=40,
    M=30,       # Use M=N for full rank and M<N for rank deficient.
    lam=0.1,    # Use lam=0 for unregularized experiments.
    n_iter=200,
    plot_iterations=200,
    n_trials=3,
    solution_location='boundary',
)
result = run_experiment(config)

# %%
output = ROOT / 'results/figures/demo.pdf'
plot_objective_gaps(result['samples'], output, result['reference_value'])
output

# %% [markdown]
# For the paper settings, restore `N=500`, use 30 trials, and select $(M,\lambda)$ according to the table in the README.
